# %%
import pandas as pd


caminho_arquivo_excel = caminho_arquivo_excel = r"C:\Users\milen\OneDrive\Documentos\analise_dados\arquivoa.xlsx"
df_principal = pd.read_excel(caminho_arquivo_excel, sheet_name= "principal")
df_ticker = pd.read_excel(caminho_arquivo_excel, sheet_name= "ticker")
                        
# Carregar o arquivo Excel em um DataFrame do Pandas
dados_excel = pd.read_excel(caminho_arquivo_excel)

# Exibir os primeiros registros do DataFrame
dados_excel.head(10)
# Out:
#   Ticker            Nome
# 0  MGLU3  Magazine Luiza
# 1  HAPV3         Hapvida
# 2  PETR4       Petrobras
# 3  B3SA3              B3
# 4  USIM5        Usiminas
# 5  CVCB3             CVC
# 6  CIEL3           Cielo
# 7  VALE3            Vale
# 8  GOLL4             GOL
# 9  BBDC4  Banco Bradesco
